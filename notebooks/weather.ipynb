# %%
# Step 1: Install the necessary libraries
# !pip install requests folium branca

# Step 2: Import the necessary libraries
import requests
import folium
from folium.plugins import MarkerCluster
import json

# Step 3: Get the data from the NWS API
nws_api_url = "https://api.weather.gov/alerts/active"
response = requests.get(nws_api_url)
data = response.json()

# Step 4: Extract the necessary information and create a list of coordinates and alert descriptions
coordinates = []
descriptions = []

for alert in data['features']:
    if alert['geometry'] is not None and len(alert['geometry']['coordinates']) >= 2:
        lat = alert['geometry']['coordinates'][1]
        lon = alert['geometry']['coordinates'][0]
        desc = alert['properties']['headline']
        coordinates.append([lat, lon])
        descriptions.append(desc)

# Step 5: Create the OpenStreetMap with MarkerClusters
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4)  # Centered on the United States

marker_cluster = MarkerCluster().add_to(m)

for coord, desc in zip(coordinates, descriptions):
    folium.Marker(
        location=coord,
        popup=desc,
    ).add_to(marker_cluster)

m
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Step 1: Install the necessary libraries
# !pip install requests folium branca

# Step 2: Import the necessary libraries
import requests
import folium
from folium.plugins import MarkerCluster
import json
import warnings

# Step 3: Get the data from the NWS API
nws_api_url = "https://api.weather.gov/alerts/active"
response = requests.get(nws_api_url)
data = response.json()

# Step 4: Extract the necessary information and create a list of coordinates and alert descriptions
coordinates = []
descriptions = []

for alert in data['features']:
    if alert['geometry'] is not None:
        if len(alert['geometry']['coordinates']) >= 2:
            lat = alert['geometry']['coordinates'][1]
            lon = alert['geometry']['coordinates'][0]
            desc = alert['properties']['headline']
            coordinates.append([lat, lon])
            descriptions.append(desc)
        else:
            warnings.warn(f"Unexpected coordinates data for alert {alert['id']}: {alert['geometry']['coordinates']}")
    else:
        warnings.warn(f"No geometry data for alert {alert['id']}")

# Step 5: Create the OpenStreetMap with MarkerClusters
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4)  # Centered on the United States

marker_cluster = MarkerCluster().add_to(m)

for coord, desc in zip(coordinates, descriptions):
    folium.Marker(
        location=coord,
        popup=desc,
    ).add_to(marker_cluster)

m
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# /tmp/ipykernel_18430/54796440.py:29: UserWarning: Unexpected coordinates data for alert https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.92f94eef49ecdb8ef79f3c51e805856eb623b647.001.1: [[[-115.36, 41.03], [-115.36, 41.050000000000004], [-115.28, 41.07000000000001], [-115.3, 41.22999990000001], [-115.27, 41.26000000000001], [-115.25999999999999, 41.47000000000001], [-115.21999999999998, 41.47999990000001], [-115.21999999999998, 41.27000000000001], [-115.25999999999999, 41.22000000000001], [-115.24, 41.12000000000001], [-115.22999999999999, 41.070000000000014], [-115.25999999999999, 41.04000000000001], [-115.36, 41.03]]]
#   warnings.warn(f"Unexpected coordinates data for alert {alert['id']}: {alert['geometry']['coordinates']}")
# ...
